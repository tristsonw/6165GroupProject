# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Data/MAINE.csv')

df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

df.head()
# Out:
#                     location  energy  congestion  loss
# date
# 2017-01-01 00:00:00    MAINE   34.86         0.0 -0.73
# 2017-01-01 01:00:00    MAINE   33.72         0.0 -0.81
# 2017-01-01 02:00:00    MAINE   32.40         0.0 -0.80
# 2017-01-01 03:00:00    MAINE   25.88         0.0 -0.65
# 2017-01-01 04:00:00    MAINE   29.65         0.0 -0.68

# %%
year_df = df.loc['2023-01-01':'2023-12-31']
year_df.tail()
# Out:
#                     location  energy  congestion  loss
# date
# 2023-12-31 19:00:00    MAINE   33.34         0.0 -0.21
# 2023-12-31 20:00:00    MAINE   34.53         0.0 -0.15
# 2023-12-31 21:00:00    MAINE   32.16         0.0 -0.36
# 2023-12-31 22:00:00    MAINE   27.93         0.0 -0.36
# 2023-12-31 23:00:00    MAINE   27.65         0.0 -0.24

# %%
plt.plot(year_df.index, year_df['energy'])

# %%
q1_df = year_df.loc['2023-01-01':'2023-04-01']
plt.plot(q1_df.index, q1_df['energy'])
